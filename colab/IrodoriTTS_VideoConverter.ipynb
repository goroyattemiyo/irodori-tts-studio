# %% [markdown]
# # IrodoriTTS SNS Video Converter for Colab
#
# 生成した音声をSNS投稿用のMP4動画に変換するためのノートブックです。
#
# GPUは必須ではありません。ffmpegで音声と画像をMP4化します。

# %% [markdown]
# ## STEP 1：Google Driveをマウントする（任意）
#
# 動画をGoogle Driveへ保存したい場合は実行してください。
# 一時的に変換するだけならスキップできます。

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## STEP 2：Video Converter GUIを取得
#
# このリポジトリから動画変換GUIを取得します。

# %%
# %cd /content
# !rm -rf irodori-tts-studio
# !git clone https://github.com/goroyattemiyo/irodori-tts-studio.git

# %% [markdown]
# ## STEP 3：環境構築
#
# ffmpegとGradioをインストールします。

# %%
# !apt-get update -y
# !apt-get install -y ffmpeg
# !pip install -U gradio

# %% [markdown]
# ## STEP 4：GUI起動
#
# 最後に表示される gradio.live のURLを開いてください。

# %%
# %cd /content/irodori-tts-studio/app
# !python irodori_video_converter_app.py --server-name 0.0.0.0 --server-port 7860 --share
